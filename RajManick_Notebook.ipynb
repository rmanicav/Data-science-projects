# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# #Exercise 2 - Create a markdown cell with the title of the notebook. (1 pt)

# %% [markdown]
# RajManick_Notebook

# %% [markdown]
# #Exercise 3 - Create a markdown cell for an introduction. (1 pt)

# %% [markdown]
# This notebook was created for learning jupyter notebook functionalties

# %% [markdown]
# Exercise 4
# List of data science languages
# 1) Python
# 2) R
# 3) Scala
# 4) Java
# 5) SQL

# %% [markdown]
# Exercise 5 - Create a markdown cell to list data science libraries
# 1) Python - Numpy, Scikit-learn, Pandas
# 2) TensorFlow
# 3) Keras
# 4) Plotly
# 5) Caret
# 6) ggplot
# 7) Natural Language toolkit

# %% [markdown]
# Exercise 6 - Create a markdown cell with a table of Data Science tools.

# %% [markdown]
# | Date Science Tools |
# |:------------------:|
# | Jupyter Notebook |
# | JupyterLab       |
# | Apache Sparks    |
# | IBM SPSS         |
# | MatLab           |

# %% [markdown]
# Exercise 7 - Create a markdown cell introducing arithmetic expression examples.

# %% [markdown]
# Basic Arithematic operations +,-,/,*
# 1) 1 + 2 =3
# 2) 2 -1 =1
# 3) 6/3 =2
# 4) 8 * 4 =32
# 5) (2 *10) - 10 =10
# Others include //, ** etc
# 2**2 = 4

# %% [markdown]
# Exercise 8 - Create a code cell to multiply and add numbers. (2 pts)

# %%
2 + 10 + 200  # addition
# Out:
# 212

# %%
300 * 200 # Multiplication
# Out:
# 60000

# %%
(200 * 2) + 100 # multiply and add
# Out:
# 500

# %% [markdown]
# Exercise 9 - Create a code cell to convert minutes to hours.

# %%
inmins = 650 # minutess
outhours =int(inmins / 60) # get hours
outmins = inmins % 60 # get minutes
print(f"The conversion of {inmins} minutes to hours is {outhours} hours and {outmins} minutes")
# Out:
# The conversion of 650 minutes to hours is 10 hours and 50 minutes

# %% [markdown]
# Exercise 10 -Insert a markdown cell to list Objectives.

# %% [markdown]
# Objectives for taking this course are
# 1) Refresh data science concepts
# 2) Upskill on data science and Machine Learning
# 3) Tackle Job interview questions
# 4) Get certification for applying for jobs

# %% [markdown]
# Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)

# %% [markdown]
# Rajesh Manicavasagam

# %% [markdown]
# Exercise 12 - Share your notebook through GitHub (3 pts)
